# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv("car data.csv") 
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.shape
# Out:
# (301, 9)

# %%
data.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
numerical_feature =[feature for feature in data.columns if data[feature].dtype !='O']
numerical_feature
# Out:
# ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
categorical_feature =[feature for feature in data.columns if data[feature].dtype =='O']
categorical_feature
# Out:
# ['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission']

# %%
data[categorical_feature].head()
# Out:
#   Car_Name Fuel_Type Seller_Type Transmission
# 0     ritz    Petrol      Dealer       Manual
# 1      sx4    Diesel      Dealer       Manual
# 2     ciaz    Petrol      Dealer       Manual
# 3  wagon r    Petrol      Dealer       Manual
# 4    swift    Diesel      Dealer       Manual

# %%
for feature in categorical_feature:
    print("the feature is {} and number of catagories are {}" .format(feature,len(data[feature].unique())))
# Out:
# the feature is Car_Name and number of catagories are 98
# the feature is Fuel_Type and number of catagories are 3
# the feature is Seller_Type and number of catagories are 2
# the feature is Transmission and number of catagories are 2

# %%
#one hot  encoding

# %%
 data =data.drop(["Car_Name"] ,axis =1)

# %%
data =pd.get_dummies(data,drop_first =True)

# %%
data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  2014           3.35           5.59       27000      0                 0
# 1  2013           4.75           9.54       43000      0                 1
# 2  2017           7.25           9.85        6900      0                 0
# 3  2011           2.85           4.15        5200      0                 0
# 4  2014           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
data["curent_year"] =2020

# %%
data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  2014           3.35           5.59       27000      0                 0
# 1  2013           4.75           9.54       43000      0                 1
# 2  2017           7.25           9.85        6900      0                 0
# 3  2011           2.85           4.15        5200      0                 0
# 4  2014           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  curent_year
# 0                 1                       0                    1         2020
# 1                 0                       0                    1         2020
# 2                 1                       0                    1         2020
# 3                 1                       0                    1         2020
# 4                 0                       0                    1         2020

# %%
data["Nu_Old_Year"] =data["curent_year"] -data["Year"]

# %%
data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  2014           3.35           5.59       27000      0                 0
# 1  2013           4.75           9.54       43000      0                 1
# 2  2017           7.25           9.85        6900      0                 0
# 3  2011           2.85           4.15        5200      0                 0
# 4  2014           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  curent_year  \
# 0                 1                       0                    1         2020
# 1                 0                       0                    1         2020
# 2                 1                       0                    1         2020
# 3                 1                       0                    1         2020
# 4                 0                       0                    1         2020
#
#    Nu_Old_Year
# 0            6
# ...

# %%
data =data.drop(["Year","curent_year"],axis =1)

# %%
data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0                 0
# 1           4.75           9.54       43000      0                 1
# 2           7.25           9.85        6900      0                 0
# 3           2.85           4.15        5200      0                 0
# 4           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  Nu_Old_Year
# 0                 1                       0                    1            6
# 1                 0                       0                    1            7
# 2                 1                       0                    1            3
# 3                 1                       0                    1            9
# 4                 0                       0                    1            6

# %%
data.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
# Nu_Old_Year                 -0.236141       0.047584    0.524342  0.182104
#
#                         Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price                   0.552339         -0.540571
# Present_Price                   0.473306         -0.465244
# ...

# %%
sns.pairplot(data)

# %%
data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0                 0
# 1           4.75           9.54       43000      0                 1
# 2           7.25           9.85        6900      0                 0
# 3           2.85           4.15        5200      0                 0
# 4           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  Nu_Old_Year
# 0                 1                       0                    1            6
# 1                 0                       0                    1            7
# 2                 1                       0                    1            3
# 3                 1                       0                    1            9
# 4                 0                       0                    1            6

# %%
real_x =data.iloc[:,1:]
real_y =data.iloc[:,0]

# %%
real_x
# Out:
#      Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0             5.59       27000      0                 0                 1
# 1             9.54       43000      0                 1                 0
# 2             9.85        6900      0                 0                 1
# 3             4.15        5200      0                 0                 1
# 4             6.87       42450      0                 1                 0
# ..             ...         ...    ...               ...               ...
# 296          11.60       33988      0                 1                 0
# 297           5.90       60000      0                 0                 1
# 298          11.00       87934      0                 0                 1
# 299          12.50        9000      0                 1                 0
# 300           5.90        5464      0                 0                 1
#
#      Seller_Type_Individual  Transmission_Manual  Nu_Old_Year
# ...

# %%
 feature importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
model =ExtraTreesRegressor()
model.fit(real_x,real_y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.35135643 0.04080909 0.00046163 0.242758   0.01050684 0.12638976
#  0.15173077 0.07598748]

# %%
feat_importance =pd.Series(model.feature_importances_,index =real_x.columns)
feat_importance.nlargest(10).plot(kind ="barh")
plt.show()

# %%
data =data.drop("Owner",axis =1)

# %%
data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000                 0
# 1           4.75           9.54       43000                 1
# 2           7.25           9.85        6900                 0
# 3           2.85           4.15        5200                 0
# 4           4.60           6.87       42450                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  Nu_Old_Year
# 0                 1                       0                    1            6
# 1                 0                       0                    1            7
# 2                 1                       0                    1            3
# 3                 1                       0                    1            9
# 4                 0                       0                    1            6

# %%
real_x =data.iloc[:,1:]
real_y =data.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y =train_test_split(real_x,real_y,test_size =0.2)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random =RandomForestRegressor()

# %%
rf_random.fit(train_x,train_y)
# Out:
# RandomForestRegressor()

# %%
print(rf_random.score(test_x,test_y))
print(rf_random.score(train_x,train_y))
# Out:
# 0.8792551396702847
# 0.9812024343850191

# %%
#Hyperperameter

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {"n_estimators":n_estimators,
               "max_features":max_features,
               "max_depth":max_depth,
               "min_samples_split":min_samples_split,
               "min_samples_leaf":min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
random = RandomizedSearchCV(estimator =rf_random,param_distributions =random_grid,scoring ='neg_mean_squared_error',n_iter =10,cv =5,verbose =2,random_state =42)

# %%
random.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.9s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.0s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.9s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# ...

# %%
random.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 10}

# %%
random.best_score_
# Out:
# -3.021376747356858

# %%
pred_y6 =random.predict(test_x)
pred_y7 =random.predict(train_x)

# %%
sns.distplot(pred_y6 -test_y)

# %%
sns.distplot(pred_y7 -train_y)

# %%
plt.scatter(pred_y6,test_y)

# %%
plt.scatter(pred_y7,train_y)

# %%
import pickle
file =open("random_forest_regression_model.pkl","wb")
pickle.dump(random ,file)
